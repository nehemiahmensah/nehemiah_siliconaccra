# %%
import pandas as pd
from benfordslaw import benfordslaw

# %%
df = pd.read_csv("foodhub_order.csv")

# %%
bl = benfordslaw(alpha = 0.05)

# %%
x = df['cost_of_the_order']

# %%
results = bl.fit(x)
# Out:
# [benfordslaw] >Analyzing digit position: [1]
# [benfordslaw] >[chi2] Anomaly detected! P=2.7759e-138, Tstat=664.744

# %%
bl.plot(title = "FRAUD DETECTION")
# Out:
# (<Figure size 1500x800 with 1 Axes>,
#  <Axes: title={'center': 'FRAUD DETECTION\nAnomaly detected! P=2.7759e-138, Tstat=664.744'}, xlabel='Digits', ylabel='Frequency (%)'>)
