# %%
import pandas as pd
import numpy as np

# %%
tbl = pd.read_html("https://zhenhub.com/blog/what-are-hs-hts-codes/")

# %%
tbl
# Out:
# [             0                                          1                   2
#  0     SECTIONS                                   CATEGORY            CHAPTERS
#  1    Section 1                   Animal & Animal Products         Chapter 1-5
#  2    Section 2                         Vegetable Products       Chapters 6-14
#  3    Section 3          Animal or Vegetable Fats and Oils          Chapter 15
#  4    Section 4                        Prepared Foodstuffs       Chapter 16-24
#  5    Section 5                           Mineral Products       Chapter 25-27
#  6    Section 6              Chemicals & Allied Industries       Chapter 28-38
#  7    Section 7                         Plastics / Rubbers  Chapters 39 and 40
#  8    Section 8          Raw Hides, Skins, Leather, & Furs       Chapter 41-43
#  9    Section 9                       Wood & Wood Products      Chapters 44-46
#  10  Section 10  Pulp of Wood or of Other Fibrous Material      Chapters 47-49
# ...

# %%
tbl = tbl[0]

# %%
tbl.columns = tbl.iloc[0]

# %%
tbl = tbl.iloc[1:,:]

# %%
tbl
# Out:
# 0     SECTIONS                                   CATEGORY            CHAPTERS
# 1    Section 1                   Animal & Animal Products         Chapter 1-5
# 2    Section 2                         Vegetable Products       Chapters 6-14
# 3    Section 3          Animal or Vegetable Fats and Oils          Chapter 15
# 4    Section 4                        Prepared Foodstuffs       Chapter 16-24
# 5    Section 5                           Mineral Products       Chapter 25-27
# 6    Section 6              Chemicals & Allied Industries       Chapter 28-38
# 7    Section 7                         Plastics / Rubbers  Chapters 39 and 40
# 8    Section 8          Raw Hides, Skins, Leather, & Furs       Chapter 41-43
# 9    Section 9                       Wood & Wood Products      Chapters 44-46
# 10  Section 10  Pulp of Wood or of Other Fibrous Material      Chapters 47-49
# 11  Section 11                                   Textiles      Chapters 50-63
# ...

# %%
tbl['HS HEAD CODE'] = ["0101-0599","0601-1499","1501-1599","1600-2400","2500-2700","2800-3800","3900-4000","4100-4300","4400-4600","4700-4900","5000-6300","6400-6700","6800-7000","7100-7199","7200-8300","8400-8500","8600-8900","9000-9200","9300-9399","9400-9600","9700-9799"]
# Out:
# C:\Users\Mence\AppData\Local\Temp\ipykernel_17628\4148057122.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tbl['HS HEAD CODE'] = ["0101-0599","0601-1499","1501-1599","1600-2400","2500-2700","2800-3800","3900-4000","4100-4300","4400-4600","4700-4900","5000-6300","6400-6700","6800-7000","7100-7199","7200-8300","8400-8500","8600-8900","9000-9200","9300-9399","9400-9600","9700-9799"]

# %%
tbl
# Out:
# 0     SECTIONS                                   CATEGORY            CHAPTERS  \
# 1    Section 1                   Animal & Animal Products         Chapter 1-5
# 2    Section 2                         Vegetable Products       Chapters 6-14
# 3    Section 3          Animal or Vegetable Fats and Oils          Chapter 15
# 4    Section 4                        Prepared Foodstuffs       Chapter 16-24
# 5    Section 5                           Mineral Products       Chapter 25-27
# 6    Section 6              Chemicals & Allied Industries       Chapter 28-38
# 7    Section 7                         Plastics / Rubbers  Chapters 39 and 40
# 8    Section 8          Raw Hides, Skins, Leather, & Furs       Chapter 41-43
# 9    Section 9                       Wood & Wood Products      Chapters 44-46
# 10  Section 10  Pulp of Wood or of Other Fibrous Material      Chapters 47-49
# 11  Section 11                                   Textiles      Chapters 50-63
# ...

# %%
tbl.to_csv('HSCODE HEADERS.csv')

# %%
tbl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 1 to 21
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SECTIONS      21 non-null     object
#  1   CATEGORY      21 non-null     object
#  2   CHAPTERS      21 non-null     object
#  3   HS HEAD CODE  21 non-null     object
# dtypes: object(4)
# memory usage: 804.0+ bytes

# %%
tbl.astype({'HS HEAD CODE':'int'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 tbl.astype({'HS HEAD CODE':'int'})
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6226, in NDFrame.astype(self, dtype, copy, errors)
#    6224             res_col = col.copy() if copy else col
#    6225         else:
# -> 6226             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6227         results.append(res_col)
#    6229 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    6230     # GH 18099/22869: columnwise conversion to extension dtype
#    6231     # GH 24704: use iloc to handle duplicate column names
#    6232     # TODO(EA2D): special case not needed with 2D EAs
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
# ...
