# %% [markdown]
# ### DATA 1

# %%
import pandas as pd

df = pd.read_html("https://www.espn.com/nba/team/stats/_/name/gs/golden-state-warriors")

# %%
player_names = df[0]

# %%
stats = df[1]

# %%
player_data = pd.concat([player_names,stats],axis=1)

# %%
player_data.dtypes ##player_data.select_dtypes('number') or ('category')
# Out:
# Name       object
# GP          int64
# GS        float64
# MIN       float64
# PTS       float64
# OR        float64
# DR        float64
# REB       float64
# AST       float64
# STL       float64
# BLK       float64
# TO        float64
# PF        float64
# AST/TO    float64
# dtype: object

# %%
player_data[["Name","GP"]].dtypes
# Out:
# Name    object
# GP       int64
# dtype: object

# %%
player_data["Name"].dtypes
# Out:
# dtype('O')

# %%
player_data = player_data.drop(18)

# %%
player_data
# Out:
#                      Name  GP    GS   MIN   PTS   OR   DR  REB  AST  STL  BLK  \
# 0        Stephen Curry PG  56  56.0  34.7  29.4  0.7  5.4  6.1  6.3  0.9  0.4
# 1        Klay Thompson SG  69  69.0  33.0  21.9  0.6  3.6  4.1  2.4  0.7  0.4
# 2         Jordan Poole SG  82  43.0  30.0  20.4  0.4  2.4  2.7  4.5  0.8  0.3
# 3       Andrew Wiggins SF  37  37.0  32.2  17.1  1.6  3.4  5.0  2.3  1.2  0.8
# 4     Jonathan Kuminga PF  67  16.0  20.8   9.9  1.0  2.4  3.4  1.9  0.6  0.5
# 5     Donte DiVincenzo SG  72  36.0  26.3   9.4  1.1  3.4  4.5  3.5  1.3  0.1
# 6       Draymond Green PF  73  73.0  31.5   8.5  0.9  6.3  7.2  6.8  1.0  0.8
# 7          Kevon Looney F  82  70.0  23.9   7.0  3.3  5.9  9.3  2.5  0.6  0.6
# 8       James Wiseman C *  21   0.0  12.5   6.9  0.9  2.6  3.5  0.7  0.1  0.3
# 9            Ty Jerome SG  45   2.0  18.1   6.9  0.2  1.6  1.7  3.0  0.5  0.1
# 10         Anthony Lamb F  62   4.0  19.3   6.7  0.9  2.6  3.5  1.5  0.5  0.3
# ...

# %%
player_data['GS'] = player_data['GS'].astype(int)

# %%
player_data
# Out:
#                      Name  GP  GS   MIN   PTS   OR   DR  REB  AST  STL  BLK  \
# 0        Stephen Curry PG  56  56  34.7  29.4  0.7  5.4  6.1  6.3  0.9  0.4
# 1        Klay Thompson SG  69  69  33.0  21.9  0.6  3.6  4.1  2.4  0.7  0.4
# 2         Jordan Poole SG  82  43  30.0  20.4  0.4  2.4  2.7  4.5  0.8  0.3
# 3       Andrew Wiggins SF  37  37  32.2  17.1  1.6  3.4  5.0  2.3  1.2  0.8
# 4     Jonathan Kuminga PF  67  16  20.8   9.9  1.0  2.4  3.4  1.9  0.6  0.5
# 5     Donte DiVincenzo SG  72  36  26.3   9.4  1.1  3.4  4.5  3.5  1.3  0.1
# 6       Draymond Green PF  73  73  31.5   8.5  0.9  6.3  7.2  6.8  1.0  0.8
# 7          Kevon Looney F  82  70  23.9   7.0  3.3  5.9  9.3  2.5  0.6  0.6
# 8       James Wiseman C *  21   0  12.5   6.9  0.9  2.6  3.5  0.7  0.1  0.3
# 9            Ty Jerome SG  45   2  18.1   6.9  0.2  1.6  1.7  3.0  0.5  0.1
# 10         Anthony Lamb F  62   4  19.3   6.7  0.9  2.6  3.5  1.5  0.5  0.3
# ...
