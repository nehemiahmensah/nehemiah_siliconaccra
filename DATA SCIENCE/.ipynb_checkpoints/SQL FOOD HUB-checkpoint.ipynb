# %% [markdown]
# #### SETUP

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('foodhub_order.csv')

# %% [markdown]
# ##### Q1: Select all the customers that ordered cuisine type American

# %%
df.query("cuisine_type == 'American'")
# Out:
#       order_id  customer_id            restaurant_name cuisine_type  \
# 3      1477334       106968  Blue Ribbon Fried Chicken     American
# 4      1478249        76942           Dirty Bird to Go     American
# 12     1476966       129969  Blue Ribbon Fried Chicken     American
# 14     1478198        62667     Lucky's Famous Burgers     American
# 15     1477414        66222                Shake Shack     American
# ...        ...          ...                        ...          ...
# 1885   1477550        97324                Shake Shack     American
# 1886   1478277        48282          The Meatball Shop     American
# 1887   1476873       237616                Shake Shack     American
# 1891   1476981       138586                Shake Shack     American
# 1894   1477421       397537                  The Smile     American
#
#       cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 3                 29.20         Weekend          3                     25
# 4                 11.59         Weekday          4                     25
# 12                24.30         Weekend          5                     23
# 14                12.13         Weekday  Not given                     23
# 15                16.20         Weekend          5                     33
# ...                 ...             ...        ...                    ...
# 1885              29.05         Weekday          4                     27
# 1886              14.50         Weekend          5                     34
# 1887               5.82         Weekend  Not given                     26
# 1891               5.82         Weekend  Not given                     22
# 1894              12.18         Weekend          5                     31
#
#       delivery_time
# 3                15
# 4                24
# 12               17
# 14               30
# 15               25
# ...             ...
# 1885             29
# 1886             25
# 1887             30
# 1891             28
# 1894             19
#
# [584 rows x 9 columns]

# %% [markdown]
# #####  Q2: SELECT ALL THE RESTAURANTS WHOSE RATING COUNT IS GREATER THAN 10 AND RATING MEAN GREATER THAN THE AVERAGE RATING MEAN OF ALL THE RESTAURANT

# %%
df.head(5)
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not given                     25
# 1              12.08         Weekend  Not given                     25
# 2              12.23         Weekday          5                     23
# 3              29.20         Weekend          3                     25
# 4              11.59         Weekday          4                     25
#
#    delivery_time
# 0             20
# 1             23
# 2             28
# 3             15
# 4             24

# %%
df.rating = df.rating.replace('Not given',np.nan)

# %%
df = df.astype({'rating':'float'})

# %%
df.groupby('restaurant_name').sum('rating').sort_values(by = 'rating' ,ascending = False)
# Out:
#                                order_id  customer_id  cost_of_the_order  \
# restaurant_name
# Shake Shack                   323578315     41827816            3579.53
# The Meatball Shop             195029322     20650082            2145.21
# Blue Ribbon Sushi             175813497     19453411            1903.95
# Blue Ribbon Fried Chicken     141840344     17671001            1662.29
# RedFarm Broadway               87175249     11458134             965.13
# ...                                 ...          ...                ...
# Coppola's East                  1478205        65361              13.05
# Crema Restaurante               1477494       300003              15.86
# Gaia Italian Cafe               1478059        53947               8.78
# Tarallucci e Vino Restaurant    2954556       209096              40.69
# Lamarca Pasta                   1477935       378482               9.22
#
#                               rating  food_preparation_time  delivery_time
# restaurant_name
# Shake Shack                    569.0                   6120           5401
# The Meatball Shop              379.0                   3588           3200
# Blue Ribbon Sushi              308.0                   3323           2849
# Blue Ribbon Fried Chicken      277.0                   2611           2318
# RedFarm Broadway               174.0                   1628           1366
# ...                              ...                    ...            ...
# Coppola's East                   0.0                     32             16
# Crema Restaurante                0.0                     31             30
# Gaia Italian Cafe                0.0                     25             15
# Tarallucci e Vino Restaurant     0.0                     49             48
# Lamarca Pasta                    0.0                     23             19
#
# [178 rows x 6 columns]

# %%
df.restaurant_name.value_counts()[0]
# Out:
# 219

# %%
mean_table = df

# %%
mean_table['rating_mean'] = mean_table.rating / len(mean_table.rating)

# %%
mean_table
# Out:
#       order_id  customer_id                        restaurant_name  \
# 0      1477147       337525                                Hangawi
# 1      1477685       358141              Blue Ribbon Sushi Izakaya
# 2      1477070        66393                            Cafe Habana
# 3      1477334       106968              Blue Ribbon Fried Chicken
# 4      1478249        76942                       Dirty Bird to Go
# ...        ...          ...                                    ...
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week  rating  \
# 0            Korean              30.75         Weekend     NaN
# 1          Japanese              12.08         Weekend     NaN
# 2           Mexican              12.23         Weekday     5.0
# 3          American              29.20         Weekend     3.0
# 4          American              11.59         Weekday     4.0
# ...             ...                ...             ...     ...
# 1893        Mexican              22.31         Weekend     5.0
# 1894       American              12.18         Weekend     5.0
# 1895       Japanese              25.22         Weekday     NaN
# 1896  Mediterranean              12.18         Weekday     5.0
# 1897       Japanese              19.45         Weekend     NaN
#
#       food_preparation_time  delivery_time  rating_mean
# 0                        25             20          NaN
# 1                        25             23          NaN
# 2                        23             28     0.002634
# 3                        25             15     0.001581
# 4                        25             24     0.002107
# ...                     ...            ...          ...
# 1893                     31             17     0.002634
# 1894                     31             19     0.002634
# 1895                     31             24          NaN
# 1896                     23             31     0.002634
# 1897                     28             24          NaN
#
# [1898 rows x 10 columns]

# %%
mean_table['sum_avg_mean'] = (mean_table.rating_mean.sum())/len(mean_table.rating_mean)

# %%
mean_table
# Out:
#       order_id  customer_id                        restaurant_name  \
# 0      1477147       337525                                Hangawi
# 1      1477685       358141              Blue Ribbon Sushi Izakaya
# 2      1477070        66393                            Cafe Habana
# 3      1477334       106968              Blue Ribbon Fried Chicken
# 4      1478249        76942                       Dirty Bird to Go
# ...        ...          ...                                    ...
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week  rating  \
# 0            Korean              30.75         Weekend     NaN
# 1          Japanese              12.08         Weekend     NaN
# 2           Mexican              12.23         Weekday     5.0
# 3          American              29.20         Weekend     3.0
# 4          American              11.59         Weekday     4.0
# ...             ...                ...             ...     ...
# 1893        Mexican              22.31         Weekend     5.0
# 1894       American              12.18         Weekend     5.0
# 1895       Japanese              25.22         Weekday     NaN
# 1896  Mediterranean              12.18         Weekday     5.0
# 1897       Japanese              19.45         Weekend     NaN
#
#       food_preparation_time  delivery_time  rating_mean  sum_avg_mean
# 0                        25             20          NaN      0.001401
# 1                        25             23          NaN      0.001401
# 2                        23             28     0.002634      0.001401
# 3                        25             15     0.001581      0.001401
# 4                        25             24     0.002107      0.001401
# ...                     ...            ...          ...           ...
# 1893                     31             17     0.002634      0.001401
# 1894                     31             19     0.002634      0.001401
# 1895                     31             24          NaN      0.001401
# 1896                     23             31     0.002634      0.001401
# 1897                     28             24          NaN      0.001401
#
# [1898 rows x 11 columns]

# %%
rating_sum = mean_table.groupby("restaurant_name").sum('rating').query("`rating` > 10").sort_values(by = 'rating' , ascending = False)# and `rating_mean` > `sum_avg_mean`")
rsum = rating_sum.loc[:,['rating']]

# %%
rsum = rsum.reset_index()

# %%
rsum.rating
# Out:
# 0     569.0
# 1     379.0
# 2     308.0
# 3     277.0
# 4     174.0
#       ...
# 67     13.0
# 68     13.0
# 69     12.0
# 70     12.0
# 71     11.0
# Name: rating, Length: 72, dtype: float64

# %% [markdown]
# ##### Q3: WHICH DAY OF THE WEEK HAS THE MOST OTHER FOR THAI FOOD

# %%
#df[df.cuisine_type == "Thai"].day_of_the_week.value_counts().plot(kind = 'bar')

# %%
df.query("cuisine_type == 'Thai'").value_counts().groupby("day_of_the_week").sum()
# Out:
# day_of_the_week
# Weekday    1
# Weekend    8
# dtype: int64

# %%
df
# Out:
#       order_id  customer_id                        restaurant_name  \
# 0      1477147       337525                                Hangawi
# 1      1477685       358141              Blue Ribbon Sushi Izakaya
# 2      1477070        66393                            Cafe Habana
# 3      1477334       106968              Blue Ribbon Fried Chicken
# 4      1478249        76942                       Dirty Bird to Go
# ...        ...          ...                                    ...
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week  rating  \
# 0            Korean              30.75         Weekend     NaN
# 1          Japanese              12.08         Weekend     NaN
# 2           Mexican              12.23         Weekday     5.0
# 3          American              29.20         Weekend     3.0
# 4          American              11.59         Weekday     4.0
# ...             ...                ...             ...     ...
# 1893        Mexican              22.31         Weekend     5.0
# 1894       American              12.18         Weekend     5.0
# 1895       Japanese              25.22         Weekday     NaN
# 1896  Mediterranean              12.18         Weekday     5.0
# 1897       Japanese              19.45         Weekend     NaN
#
#       food_preparation_time  delivery_time  rating_mean  sum_avg_mean
# 0                        25             20          NaN      0.001401
# 1                        25             23          NaN      0.001401
# 2                        23             28     0.002634      0.001401
# 3                        25             15     0.001581      0.001401
# 4                        25             24     0.002107      0.001401
# ...                     ...            ...          ...           ...
# 1893                     31             17     0.002634      0.001401
# 1894                     31             19     0.002634      0.001401
# 1895                     31             24          NaN      0.001401
# 1896                     23             31     0.002634      0.001401
# 1897                     28             24          NaN      0.001401
#
# [1898 rows x 11 columns]

# %%
df_counts = df.restaurant_name.value_counts().reset_index()

# %%
df_counts.columns = ['restaurant_name','counts']

# %%
df_counts['rating_sum'] = rsum.rating

# %%
df_counts
# Out:
#                restaurant_name  counts  rating_sum
# 0                  Shake Shack     219       569.0
# 1            The Meatball Shop     132       379.0
# 2            Blue Ribbon Sushi     119       308.0
# 3    Blue Ribbon Fried Chicken      96       277.0
# 4                         Parm      68       174.0
# ..                         ...     ...         ...
# 173               Sushi Choshi       1         NaN
# 174           Dos Caminos Soho       1         NaN
# 175                  La Follia       1         NaN
# 176              Philippe Chow       1         NaN
# 177                 'wichcraft       1         NaN
#
# [178 rows x 3 columns]
